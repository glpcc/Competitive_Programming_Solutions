# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib import pyplot

# %%
df = pd.read_csv('data.csv')

# %%
df_scaled = StandardScaler().fit_transform(df)
# Out:
# array([[ 1.61927542,  1.1654484 ,  1.12351875,  1.61815031, -2.00697359],
#        [ 0.50790326,  0.6057205 ,  0.60113435,  0.51293699,  0.73452641],
#        [-0.80127275, -0.51008133, -0.4634463 , -0.80313217,  0.09124376],
#        ...,
#        [-0.07735143,  0.21774292,  0.22344188, -0.08224664,  0.70407902],
#        [ 1.1808442 ,  0.96734195,  0.93231298,  1.17963403,  1.4556077 ],
#        [ 0.96672663,  0.85526391,  0.8370376 ,  0.96711278,  0.86422362]])

# %%
pca = PCA(2)
prcomp = pca.fit_transform(df_scaled)
prcomp.std(axis=0)
# Out:
# array([1.96911276, 0.99780426])

# %%
pyplot.scatter(-prcomp[:,0],-prcomp[:,1])
